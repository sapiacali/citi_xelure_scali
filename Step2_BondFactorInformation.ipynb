# %% [markdown]
# Created BY: Sapia Cali <br>
# Created Date: 11-24-2022 <br>
# Description: Step 2

# %%
from sqlalchemy import create_engine
import pandas as pd
import time
import datetime

# %%
# %load_ext sql

# %%
engine = create_engine("mysql+pymysql://" + "root" + ":" + "" + "@" + "localhost" + ":" + "3306" + "/" + "dwh_finance" + "?" + "charset=utf8mb4")

# %%
# %sql $engine.url
# Out:
# 'Connected: root@dwh_finance'

# %%
#drop t_bond_factor_information this cell is for Pia only
#bond_factor_information_truncate = %sql DROP TABLE t_bond_factor_information

# %%
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)

# %% [markdown]
# ### Import Data with Excel File
# The excel file should be from the Bond Factor Information category (2006 and 2007)

# %% [markdown]
# #### <font color='red'>Note: Enter the exact name of the excel file you want to insert into the table </font>

# %%
#excel_file = pd.read_csv('BondFile/BondExtCMLT06AMC10709.csv')
#df = pd.DataFrame(data=excel_file)
#df.sample()
# Out:
#      Deal Name      CUSIP Class Name Payment Date  \
# 14  CMLT06AMC1  17309PAL0         m8    9/25/2007
#
#     Original Principal Balance $  Prior Principal Balance $  \
# 14                     9366000.0                  9366000.0
#
#     Prior Principal Balance Factor  Current Principal Balance $  \
# 14                          1000.0                    9366000.0
#
#     Current Principal Balance Factor  Interest Paid $  Interest Paid Factor  \
# 14                            1000.0         49456.38              5.280416
#
#     Principal Paid $  Principal Paid Factor  Deferred Interest $  \
# 14               0.0                    0.0                    0
#
#     Deferred Interest Factor  Principal Balance Adjustment $  \
# 14                         0                               0
#
#     Principal Balance Adjustment Factor  Current Pass-Thru Rate  \
# 14                                    0                   6.555
#
#     Next Pass-Thru Rate  Other
# ...

# %% [markdown]
# ### Data Cleaning

# %%
#remove replace column name
df.columns = df.columns.str.replace(' ','_')  
df.columns = df.columns.str.replace('#','num')
df = df.rename(columns=str.lower)
df.sample()
# Out:
#     deal_name      cusip class_name payment_date  \
# 3  CMLT06AMC1  17309PAC0        a2c    9/25/2007
#
#    original_principal_balance_$  prior_principal_balance_$  \
# 3                     7144000.0                  7144000.0
#
#    prior_principal_balance_factor  current_principal_balance_$  \
# 3                          1000.0                    7144000.0
#
#    current_principal_balance_factor  interest_paid_$  interest_paid_factor  \
# 3                            1000.0         33176.93              4.644027
#
#    principal_paid_$  principal_paid_factor  deferred_interest_$  \
# 3               0.0                    0.0                    0
#
#    deferred_interest_factor  principal_balance_adjustment_$  \
# 3                         0                               0
#
#    principal_balance_adjustment_factor  current_pass-thru_rate  \
# 3                                    0                   5.765
#
#    next_pass-thru_rate  other
# 3                 0.26    NaN

# %%
df['payment_date'] = pd.to_datetime(df.payment_date)
df.sample()
# Out:
#      deal_name      cusip class_name payment_date  \
# 12  CMLT06AMC1  17309PAJ5         m6   2007-09-25
#
#     original_principal_balance_$  prior_principal_balance_$  \
# 12                    14362000.0                 14362000.0
#
#     prior_principal_balance_factor  current_principal_balance_$  \
# 12                          1000.0                   14362000.0
#
#     current_principal_balance_factor  interest_paid_$  interest_paid_factor  \
# 12                            1000.0         70052.65              4.877639
#
#     principal_paid_$  principal_paid_factor  deferred_interest_$  \
# 12               0.0                    0.0                    0
#
#     deferred_interest_factor  principal_balance_adjustment_$  \
# 12                         0                               0
#
#     principal_balance_adjustment_factor  current_pass-thru_rate  \
# 12                                    0                   6.055
#
#     next_pass-thru_rate  other
# ...

# %%
# Delete duplicate rows 
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (19, 20)

# %%
current_date = datetime.datetime.now()
date_today = str(current_date.year)+('-')+str(current_date.month)+('-')+str(current_date.day)
# Input date today
df['import_date'] = date_today

# %%
 #df.to_sql(con=engine,name='t_bond_factor_information',if_exists='append',index=False)
# Out:
# 19

# %%
df.sample()
# Out:
#     deal_name      cusip class_name payment_date  \
# 5  CMLT06AMC1  17309PAD8         m1   2007-09-25
#
#    original_principal_balance_$  prior_principal_balance_$  \
# 5                    44334000.0                 44334000.0
#
#    prior_principal_balance_factor  current_principal_balance_$  \
# 5                          1000.0                   44334000.0
#
#    current_principal_balance_factor  interest_paid_$  interest_paid_factor  \
# 5                            1000.0        206959.73              4.668194
#
#    principal_paid_$  principal_paid_factor  deferred_interest_$  \
# 5               0.0                    0.0                    0
#
#    deferred_interest_factor  principal_balance_adjustment_$  \
# 5                         0                               0
#
#    principal_balance_adjustment_factor  current_pass-thru_rate  \
# 5                                    0                   5.795
#
#    next_pass-thru_rate  other import_date
# ...

# %%
bond_factor_information = %sql SELECT * FROM t_bond_factor_information
bond_factor_information = pd.DataFrame(data=bond_factor_information)
bond_factor_information.head()
# Out:
#  * mysql+pymysql://root:***@localhost:3306/dwh_finance?charset=utf8mb4
# 260 rows affected.
#     deal_name      cusip class_name payment_date  \
# 0  CMLT06AMC1  17309PAS5         a1   2006-10-25
# 1  CMLT06AMC1  17309PAA4        a2a   2006-10-25
# 2  CMLT06AMC1  17309PAB2        a2b   2006-10-25
# 3  CMLT06AMC1  17309PAC0        a2c   2006-10-25
# 4  CMLT06AMC1  17309PAP1         ce   2006-10-25
#
#    original_principal_balance_$  prior_principal_balance_$  \
# 0                  6.020070e+08               6.020070e+08
# 1                  2.082540e+08               2.082540e+08
# 2                  1.691860e+08               1.691860e+08
# 3                  7.144000e+06               7.144000e+06
# 4                  2.560228e+07               2.560228e+07
#
#    prior_principal_balance_factor  current_principal_balance_$  \
# 0                            1000                 5.885687e+08
# 1                            1000                 1.987027e+08
# ...

# %%
bond_factor_information = bond_factor_information.drop_duplicates()

# %%
bond_factor_information = bond_factor_information.groupby(['deal_name','payment_date'])['payment_date'].count().reset_index(name = 'bond_factor_information_count')
bond_factor_information
# Out:
#      deal_name payment_date  bond_factor_information_count
# 0    CMLT05WF2   2006-10-25                             10
# 1    CMLT05WF2   2006-12-26                             10
# 2    CMLT05WF2   2007-01-25                             10
# 3    CMLT05WF2   2007-06-25                             10
# 4     CMLT06A5   2006-11-27                             11
# 5   CMLT06AMC1   2006-10-25                             19
# 6   CMLT06AMC1   2006-11-27                             19
# 7   CMLT06AMC1   2006-12-26                             19
# 8   CMLT06AMC1   2007-01-25                             19
# 9   CMLT06AMC1   2007-02-26                             19
# 10  CMLT06AMC1   2007-03-26                             19
# 11  CMLT06AMC1   2007-05-25                             19
# 12  CMLT06AMC1   2007-06-25                             19
# 13  CMLT06AMC1   2007-07-25                             19
# 14  CMLT06AMC1   2007-08-27                             19
# ...
