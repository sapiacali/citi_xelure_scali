# %% [markdown]
# Created BY: Sapia Cali <br>
# Created Date: 11-24-2022 <br>
# Description: Step 1

# %%
from sqlalchemy import create_engine
import pandas as pd
import time
import datetime

# %%
# %load_ext sql

# %%
engine = create_engine("mysql+pymysql://" + "root" + ":" + "" + "@" + "localhost" + ":" + "3306" + "/" + "dwh_finance" + "?" + "charset=utf8mb4")

# %%
# %sql $engine.url
# Out:
# 'Connected: root@dwh_finance'

# %%
#drop t_loan_level_data this cell is for Pia only
#loan_level_data_truncate = %sql DROP TABLE t_loan_level_data

# %%
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)

# %% [markdown]
# ### Import Data with Excel File
# The excel file should be from the Loan Level Data category (2006 and 2007)

# %% [markdown]
# #### <font color='red'>Note: Enter the exact name of the excel file you want to insert into the table </font>

# %%
#excel_file = pd.read_csv('ExcelFile/ColExtCMLT06AMC10709.csv')
#df = pd.DataFrame(data=excel_file)
#df.sample()
# Out:
#       Loan Identification Number  Property Type Code  Occupancy Code  \
# 3763                   146038401                   2               1
#
#       Loan Pupose Code  Note Type Code  Current Interest Rate  Pool Number  \
# 3763                 3               2                   7.99            2
#
#       Original Loan Balance  Current Loan Balance  First Payment Date  \
# 3763               454480.0              454480.0                 406
#
#       Maturity Date  Current P&I Constant  Original Stated Term in Months  \
# 3763            336               3026.08                             360
#
#       Foreclosure/Bankruptcy Code  LTV Ratio at Origination State Code  \
# 3763                            0                      90.0         CA
#
#       Participation Code  Percentage Retained or Purchased  \
# 3763                 NaN                                 0
#
#       Interest Paid to Date  Amortization Type Code  \
# ...

# %% [markdown]
# ### Data Cleaning

# %%
#remove replace column name
df.columns = df.columns.str.replace(' ','_')  
df.columns = df.columns.str.replace('#','num')
df = df.rename(columns=str.lower)
df.sample()
# Out:
#     loan_identification_number  property_type_code  occupancy_code  \
# 93                    96962238                   0               3
#
#     loan_pupose_code  note_type_code  current_interest_rate  pool_number  \
# 93                 3               1                   9.35            1
#
#     original_loan_balance  current_loan_balance  first_payment_date  \
# 93               121500.0             120522.56                 706
#
#     maturity_date  current_p&i_constant  original_stated_term_in_months  \
# 93            636               1008.37                             360
#
#     foreclosure/bankruptcy_code  ltv_ratio_at_origination state_code  \
# 93                            0                      90.0         NY
#
#     participation_code  percentage_retained_or_purchased  \
# 93                 NaN                                 0
#
#     interest_paid_to_date  amortization_type_code  \
# 93                80701.0                       1
#
# ...

# %%
# Add deal_id with CMLT06AMC1
df['deal_id'] = 'CMLT06AMC1'

# %% [markdown]
# #### <font color='red'>Note: Check the exact distribution date from the pdf of Certificate Holders Statement </font>

# %%
# Enter the distribution_date same with in the pdf File. Date format YYYY-MM-DD
df['distribution_date'] = '2007-09-25'

# %%
df.head()
# Out:
#    loan_identification_number  property_type_code  occupancy_code  \
# 0                    97890198                   0               1
# 1                    98232192                   0               3
# 2                   149634024                   0               1
# 3                    97026637                   0               3
# 4                    97559074                   0               3
#
#    loan_pupose_code  note_type_code  current_interest_rate  pool_number  \
# 0                 1               2                  8.900            2
# 1                 1               2                  8.425            1
# 2                 3               1                  9.750            1
# 3                 1               2                  9.850            1
# 4                 3               2                  9.600            1
#
#    original_loan_balance  current_loan_balance  first_payment_date  \
# ...

# %%
# Delete duplicate rows 
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (5117, 104)

# %%
df.sample()
# Out:
#       loan_identification_number  property_type_code  occupancy_code  \
# 1375                    97245195                   2               1
#
#       loan_pupose_code  note_type_code  current_interest_rate  pool_number  \
# 1375                 1               2                   8.45            2
#
#       original_loan_balance  current_loan_balance  first_payment_date  \
# 1375               404000.0              404000.0                 706
#
#       maturity_date  current_p&i_constant  original_stated_term_in_months  \
# 1375            636               2844.84                             360
#
#       foreclosure/bankruptcy_code  ltv_ratio_at_origination state_code  \
# 1375                            0                      80.0         FL
#
#       participation_code  percentage_retained_or_purchased  \
# 1375                 NaN                                 0
#
#       interest_paid_to_date  amortization_type_code  \
# ...

# %%
current_date = datetime.datetime.now()
date_today = str(current_date.year)+('-')+str(current_date.month)+('-')+str(current_date.day)
# Input date today
df['import_date'] = date_today

# %%
#df.to_sql(con=engine,name='t_loan_level_data',if_exists='append',index=False)
# Out:
# 5117

# %%
loan_level_data1 = %sql SELECT * FROM t_loan_level_data
loan_level_data1 = pd.DataFrame(data=loan_level_data1)
loan_level_data1.head()
# Out:
#  * mysql+pymysql://root:***@localhost:3306/dwh_finance?charset=utf8mb4
# 64016 rows affected.
#    loan_identification_number  property_type_code  occupancy_code  \
# 0                   149572588                   0               1
# 1                    98016793                   0               1
# 2                    96862230                   0               1
# 3                    98819030                   0               1
# 4                    95577391                   0               1
#
#    loan_pupose_code  note_type_code  current_interest_rate  pool_number  \
# 0                 3               2                   9.20            1
# 1                 3               2                   6.85            1
# 2                 3               1                   9.90            1
# 3                 3               2                   7.95            1
# 4                 1               2                   6.99            2
#
# ...

# %%
loan_level_data1 = loan_level_data1.drop_duplicates()

# %%
loan_level_data_count = loan_level_data1.groupby(['deal_id','distribution_date'])['distribution_date'].count().reset_index(name = 'loan_level_data_count')
loan_level_data_count
# Out:
#        deal_id distribution_date  loan_level_data_count
# 0   CMLT06AMC1        2006-10-25                   6522
# 1   CMLT06AMC1        2006-11-27                   6423
# 2   CMLT06AMC1        2006-12-26                   6234
# 3   CMLT06AMC1        2007-01-25                   6121
# 4   CMLT06AMC1        2007-02-26                   5839
# 5   CMLT06AMC1        2007-03-26                   5713
# 6   CMLT06AMC1        2007-04-25                   5605
# 7   CMLT06AMC1        2007-05-25                   5509
# 8   CMLT06AMC1        2007-06-25                   5417
# 9   CMLT06AMC1        2007-07-25                   5332
# 10  CMLT06AMC1        2007-08-27                    184
# 11  CMLT06AMC1        2007-09-25                   5117
